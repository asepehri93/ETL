# %%
from lammps import lammps
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-fd68e3ef4f00> in <module>
# ----> 1 from lammps import lammps
#
# ModuleNotFoundError: No module named 'lammps'

# %%
# !conda activate lmp
# Out:
# CommandNotFoundError: Your shell has not been properly configured to use 'conda activate'.
# To initialize your shell, run
#
#     $ conda init <SHELL_NAME>
#
# Currently supported shells are:
#   - bash
#   - fish
#   - tcsh
#   - xonsh
#   - zsh
#   - powershell
#
# See 'conda init --help' for more information and options.
#
# IMPORTANT: You may need to close and restart your shell after running 'conda init'.

# %%
conda init bash
# Out:
# no change     /Users/alirezas/opt/anaconda3/condabin/conda
# no change     /Users/alirezas/opt/anaconda3/bin/conda
# no change     /Users/alirezas/opt/anaconda3/bin/conda-env
# no change     /Users/alirezas/opt/anaconda3/bin/activate
# no change     /Users/alirezas/opt/anaconda3/bin/deactivate
# no change     /Users/alirezas/opt/anaconda3/etc/profile.d/conda.sh
# no change     /Users/alirezas/opt/anaconda3/etc/fish/conf.d/conda.fish
# no change     /Users/alirezas/opt/anaconda3/shell/condabin/Conda.psm1
# no change     /Users/alirezas/opt/anaconda3/shell/condabin/conda-hook.ps1
# no change     /Users/alirezas/opt/anaconda3/lib/python3.7/site-packages/xontrib/conda.xsh
# no change     /Users/alirezas/opt/anaconda3/etc/profile.d/conda.csh
# modified      /Users/alirezas/.bash_profile
#
# ==> For changes to take effect, close and re-open your current shell. <==
#
#
# Note: you may need to restart the kernel to use updated packages.
