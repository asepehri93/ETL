# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-3ffd82a13a74> in <module>
#       5
#       6 # Find the correct site-packages path (python3.12, etc.)
# ----> 7 pyver = next(d for d in os.listdir(f"{ENV}/lib") if d.startswith("python3."))
#       8 sys.path.insert(0, f"{ENV}/lib/{pyver}/site-packages")
#       9
#
# FileNotFoundError: [Errno 2] No such file or directory: '/opt/conda/envs/lmp/lib'

# %%
from lammps import lammps
lmp = lammps()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-4819209d3824> in <module>
# ----> 1 from lammps import lammps
#       2 lmp = lammps()
#
# ModuleNotFoundError: No module named 'lammps'
